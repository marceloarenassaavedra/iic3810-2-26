# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

# %%
estado = Statevector.from_label("0")
estado.draw("bloch")

# %%
estado = Statevector.from_label("1")
estado.draw("bloch")

# %%
estado = Statevector.from_label("+")
estado.draw("bloch")

# %%
estado = Statevector.from_label("-")
estado.draw("bloch")
