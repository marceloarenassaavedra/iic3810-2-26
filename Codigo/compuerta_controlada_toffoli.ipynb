# %%
import numpy as np
from qiskit.circuit.library import UnitaryGate

U = np.array([
    [0,  1],
    [1, 0]
], dtype=complex)

compuerta_U = UnitaryGate(U, label="U")
compuerta_CU = compuerta_U.control(2)

# %%
from qiskit import QuantumCircuit

circuito = QuantumCircuit(3)
circuito.x(0)
circuito.x(1)
circuito.x(2)
circuito.append(compuerta_CU,[0, 2, 1])
circuito.measure_all()
circuito.draw("mpl")

# %%
from qiskit.primitives import StatevectorSampler
from qiskit.visualization import plot_histogram

simulador = StatevectorSampler()

trabajo = simulador.run(
    [circuito],
    shots=10000
)

resultado = trabajo.result()
conteos = resultado[0].data.meas.get_counts()

plot_histogram(conteos)
